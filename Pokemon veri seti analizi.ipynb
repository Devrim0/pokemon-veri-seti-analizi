# %%
import numpy as np # cebir
import pandas as pd # veri işleme, CSV dosyaları I/O (örn. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns  # görselleştirme aracı

# Giriş veri dosyaları "../input/" dizinindedir.
# Örneğin bu hücreyi çalıştırmak için Shift+Enter'a aynı anda basarsanız hücre çalışır ve o dizindeki dosyaları sıralar.
from subprocess import check_output

# %%
veri=pd.read_csv("C:\\Users\\Devrim\\Desktop\\POKEMO\\pokemon.csv")
veri
# Out:
#                        abilities  against_bug  against_dark  against_dragon  \
# 0    ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 1    ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 2    ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 3       ['Blaze', 'Solar Power']         0.50           1.0             1.0
# 4       ['Blaze', 'Solar Power']         0.50           1.0             1.0
# ..                           ...          ...           ...             ...
# 796              ['Beast Boost']         0.25           1.0             0.5
# 797              ['Beast Boost']         1.00           1.0             0.5
# 798              ['Beast Boost']         2.00           0.5             2.0
# 799              ['Prism Armor']         2.00           2.0             1.0
# 800               ['Soul-Heart']         0.25           0.5             0.0
#
# ...

# %%
veri.tail()
# Out:
#            abilities  against_bug  against_dark  against_dragon  \
# 796  ['Beast Boost']         0.25           1.0             0.5
# 797  ['Beast Boost']         1.00           1.0             0.5
# 798  ['Beast Boost']         2.00           0.5             2.0
# 799  ['Prism Armor']         2.00           2.0             1.0
# 800   ['Soul-Heart']         0.25           0.5             0.0
#
#      against_electric  against_fairy  against_fight  against_fire  \
# 796               2.0            0.5            1.0           2.0
# 797               0.5            0.5            2.0           4.0
# 798               0.5            4.0            2.0           0.5
# 799               1.0            1.0            0.5           1.0
# 800               1.0            0.5            1.0           2.0
#
#      against_flying  against_ghost  ...  percentage_male  pokedex_number  \
# 796             0.5            1.0  ...              NaN             797
# ...

# %%
veri.columns
# Out:
# Index(['abilities', 'against_bug', 'against_dark', 'against_dragon',
#        'against_electric', 'against_fairy', 'against_fight', 'against_fire',
#        'against_flying', 'against_ghost', 'against_grass', 'against_ground',
#        'against_ice', 'against_normal', 'against_poison', 'against_psychic',
#        'against_rock', 'against_steel', 'against_water', 'attack',
#        'base_egg_steps', 'base_happiness', 'base_total', 'capture_rate',
#        'classfication', 'defense', 'experience_growth', 'height_m', 'hp',
#        'japanese_name', 'name', 'percentage_male', 'pokedex_number',
#        'sp_attack', 'sp_defense', 'speed', 'type1', 'type2', 'weight_kg',
#        'generation', 'is_legendary'],
#       dtype='object')

# %%
veri.shape
# Out:
# (801, 41)

# %%
veri.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 801 entries, 0 to 800
# Data columns (total 41 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   abilities          801 non-null    object
#  1   against_bug        801 non-null    float64
#  2   against_dark       801 non-null    float64
#  3   against_dragon     801 non-null    float64
#  4   against_electric   801 non-null    float64
#  5   against_fairy      801 non-null    float64
#  6   against_fight      801 non-null    float64
#  7   against_fire       801 non-null    float64
#  8   against_flying     801 non-null    float64
#  9   against_ghost      801 non-null    float64
#  10  against_grass      801 non-null    float64
#  11  against_ground     801 non-null    float64
#  12  against_ice        801 non-null    float64
#  13  against_normal     801 non-null    float64
#  14  against_poison     801 non-null    float64
# ...

# %%
print(veri["against_bug"].value_counts(dropna=False))
# Out:
# 1.00    376
# 0.50    247
# 2.00    128
# 0.25     42
# 4.00      8
# Name: against_bug, dtype: int64

# %%
veri.describe()
# Out:
#        against_bug  against_dark  against_dragon  against_electric  \
# count   801.000000    801.000000      801.000000        801.000000
# mean      0.996255      1.057116        0.968789          1.073970
# std       0.597248      0.438142        0.353058          0.654962
# min       0.250000      0.250000        0.000000          0.000000
# 25%       0.500000      1.000000        1.000000          0.500000
# 50%       1.000000      1.000000        1.000000          1.000000
# 75%       1.000000      1.000000        1.000000          1.000000
# max       4.000000      4.000000        2.000000          4.000000
#
#        against_fairy  against_fight  against_fire  against_flying  \
# count     801.000000     801.000000    801.000000      801.000000
# mean        1.068976       1.065543      1.135456        1.192884
# std         0.522167       0.717251      0.691853        0.604488
# min         0.250000       0.000000      0.250000        0.250000
# ...

# %%
veri.boxplot(column="against_bug",by="against_electric")
# Out:
# <AxesSubplot:title={'center':'against_bug'}, xlabel='against_electric'>

# %%
yeni_veri=veri.head()
yeni_veri
# Out:
#                      abilities  against_bug  against_dark  against_dragon  \
# 0  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 1  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 2  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 3     ['Blaze', 'Solar Power']          0.5           1.0             1.0
# 4     ['Blaze', 'Solar Power']          0.5           1.0             1.0
#
#    against_electric  against_fairy  against_fight  against_fire  \
# 0               0.5            0.5            0.5           2.0
# 1               0.5            0.5            0.5           2.0
# 2               0.5            0.5            0.5           2.0
# 3               1.0            0.5            1.0           0.5
# 4               1.0            0.5            1.0           0.5
#
#    against_flying  against_ghost  ...  percentage_male  pokedex_number  \
# ...

# %%
meltlenmis=pd.melt(frame=yeni_veri,id_vars='abilities',value_vars=['against_bug','against_electric'])
meltlenmis
# Out:
#                      abilities          variable  value
# 0  ['Overgrow', 'Chlorophyll']       against_bug    1.0
# 1  ['Overgrow', 'Chlorophyll']       against_bug    1.0
# 2  ['Overgrow', 'Chlorophyll']       against_bug    1.0
# 3     ['Blaze', 'Solar Power']       against_bug    0.5
# 4     ['Blaze', 'Solar Power']       against_bug    0.5
# 5  ['Overgrow', 'Chlorophyll']  against_electric    0.5
# 6  ['Overgrow', 'Chlorophyll']  against_electric    0.5
# 7  ['Overgrow', 'Chlorophyll']  against_electric    0.5
# 8     ['Blaze', 'Solar Power']  against_electric    1.0
# 9     ['Blaze', 'Solar Power']  against_electric    1.0

# %%
veri1=veri.head()
veri2=veri.tail()
conc_data_row=pd.concat([veri1,veri2],axis=0,ignore_index=True)
conc_data_row
# Out:
#                      abilities  against_bug  against_dark  against_dragon  \
# 0  ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 1  ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 2  ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 3     ['Blaze', 'Solar Power']         0.50           1.0             1.0
# 4     ['Blaze', 'Solar Power']         0.50           1.0             1.0
# 5              ['Beast Boost']         0.25           1.0             0.5
# 6              ['Beast Boost']         1.00           1.0             0.5
# 7              ['Beast Boost']         2.00           0.5             2.0
# 8              ['Prism Armor']         2.00           2.0             1.0
# 9               ['Soul-Heart']         0.25           0.5             0.0
#
#    against_electric  against_fairy  against_fight  against_fire  \
# 0               0.5            0.5            0.5           2.0
# ...

# %%
veri1=veri['against_bug'].head()
veri2=veri['against_electric'].head()
conc_data_col=pd.concat([veri1,veri2],axis=1)
conc_data_col
# Out:
#    against_bug  against_electric
# 0          1.0               0.5
# 1          1.0               0.5
# 2          1.0               0.5
# 3          0.5               1.0
# 4          0.5               1.0

# %%
veri.head().dtypes
# Out:
# abilities             object
# against_bug          float64
# against_dark         float64
# against_dragon       float64
# against_electric     float64
# against_fairy        float64
# against_fight        float64
# against_fire         float64
# against_flying       float64
# against_ghost        float64
# against_grass        float64
# against_ground       float64
# against_ice          float64
# against_normal       float64
# against_poison       float64
# against_psychic      float64
# against_rock         float64
# against_steel        float64
# against_water        float64
# attack                 int64
# base_egg_steps         int64
# base_happiness         int64
# base_total             int64
# capture_rate          object
# classfication         object
# defense                int64
# experience_growth      int64
# height_m             float64
# hp                     int64
# japanese_name         object
# name                  object
# percentage_male      float64
# ...

# %%
veri['abilities']=veri['abilities'].astype('category')
veri['against_electric']=veri['against_electric'].astype('int')

# %%
veri.dtypes
# Out:
# abilities            category
# against_bug           float64
# against_dark          float64
# against_dragon        float64
# against_electric        int32
# against_fairy         float64
# against_fight         float64
# against_fire          float64
# against_flying        float64
# against_ghost         float64
# against_grass         float64
# against_ground        float64
# against_ice           float64
# against_normal        float64
# against_poison        float64
# against_psychic       float64
# against_rock          float64
# against_steel         float64
# against_water         float64
# attack                  int64
# base_egg_steps          int64
# base_happiness          int64
# base_total              int64
# capture_rate           object
# classfication          object
# defense                 int64
# experience_growth       int64
# height_m              float64
# hp                      int64
# japanese_name          object
# name                   object
# ...

# %%
veri.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 801 entries, 0 to 800
# Data columns (total 41 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   abilities          801 non-null    category
#  1   against_bug        801 non-null    float64
#  2   against_dark       801 non-null    float64
#  3   against_dragon     801 non-null    float64
#  4   against_electric   801 non-null    int32
#  5   against_fairy      801 non-null    float64
#  6   against_fight      801 non-null    float64
#  7   against_fire       801 non-null    float64
#  8   against_flying     801 non-null    float64
#  9   against_ghost      801 non-null    float64
#  10  against_grass      801 non-null    float64
#  11  against_ground     801 non-null    float64
#  12  against_ice        801 non-null    float64
#  13  against_normal     801 non-null    float64
#  14  against_poison     801 non-null    float64
# ...

# %%
veri["type2"].value_counts(dropna=False)
# Out:
# NaN         384
# flying       95
# ground       34
# poison       34
# fairy        29
# psychic      29
# fighting     25
# steel        22
# dark         21
# grass        20
# dragon       17
# water        17
# ice          15
# rock         14
# ghost        14
# fire         13
# electric      9
# bug           5
# normal        4
# Name: type2, dtype: int64

# %%
veri1=veri
veri1["type2"].dropna(inplace=True)

# %%
assert 1==1

# %%
assert  veri["type2"].notnull().all()

# %%
sehir=["İspanya","Fransa"]
nufus=["11","12"]
list_label=["nufus","sehir"]
list_col=[nufus,sehir]
zipped=list(zip(list_label,list_col))
data_dict=dict(zipped)
df=pd.DataFrame(data_dict)
df
# Out:
#   nufus    sehir
# 0    11  İspanya
# 1    12   Fransa

# %%
df["baskent"]=["Madrid","paris"]
df
# Out:
#   nufus    sehir baskent
# 0    11  İspanya  Madrid
# 1    12   Fransa   paris

# %%
df["income"]=0
df
# Out:
#   nufus    sehir baskent  income
# 0    11  İspanya  Madrid       0
# 1    12   Fransa   paris       0

# %%
veri1=veri.loc[:,["sp_attack","sp_defense","speed"]]
veri2=veri.loc[:,["sp_attack"]]
veri3=veri.loc[:,["sp_defense"]]
veri4=veri.loc[:,["speed"]]
veri1.plot()
veri2.plot()
veri3.plot()
veri4.plot()
# Out:
# <AxesSubplot:>

# %%
veri1.plot(subplots=True)
plt.show()

# %%
veri1.plot(kind="scatter",x="sp_attack", y="sp_defense")
plt.show()

# %%
veri1.plot(kind = "hist",y = "sp_defense",bins = 50,range= (0,250),density=True)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
fig, axes=plt.subplots(nrows=2,ncols=1)
veri1.plot(kind="hist",y="sp_defense",bins=50,range=(0,250),density=True,ax=axes[0])
veri1.plot(kind="hist",y="sp_defense",bins=50,range=(0,250),density=True,ax=axes[1],cumulative=True)
plt.savefig('graph.png')
plt
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\Devrim\\anaconda3\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
sonuc="Tam olarak pokemon oyununu fonksiyonlarını analiz ettik"
sonuc
# Out:
# 'Tam olarak pokemon oyununu fonksiyonlarını analiz ettik'
